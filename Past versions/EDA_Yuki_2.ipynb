# %% [markdown]
# ## The Project
#
# Microsoft sees all the big companies creating original video content, and they want to get in on the fun. They have decided to create a new movie studio, but the problem is they don’t know anything about creating movies. They have hired you to help them better understand the movie industry.
# Your team is charged with doing data analysis and creating a presentation that explores what type of films are currently doing the best at the box office. You must then translate those findings into actionable insights that the CEO can use when deciding what type of films they should be creating.
#
# # The Deliverables
#
# There are three required deliverables for this project:
#
# 1. A well documented **Jupyter Notebook** containing any code you've written for this project and comments explaining it.
# 1. An organized **README.md** file in the GitHub repository that describes the contents of the repository. This file should be the source of information for navigating through the repository.
# 1. A Github repository containing all of the above files and any additional files worth includding
# 1. [OPTIONAL] A short **slide deck** (delivered as a PDF export) giving a high-level overview of your methodology and recommendations for non-technical stakeholders. If you do this, make sure to also add and commit this pdf of your non-technical presentation to your repository with a file name of presentation.pdf.
#
# ### Jupyter Notebook Must-Haves
#
# For this project, your Jupyter Notebook should meet the following specifications:
#
# #### Organization/Code Cleanliness
#
# * The notebook should be well organized, easy to follow,  and code should be commented where appropriate.
#     * Level Up: The notebook contains well-formatted, professional looking markdown cells explaining any substantial code.  All functions have [docstrings](https://numpydoc.readthedocs.io/en/latest/format.html) that act as professional-quality documentation
# * The notebook is written for technical audiences with a way to both understand your approach and reproduce your results. The target audience for this deliverable is other data scientists looking to validate your findings.
#
# #### Visualizations & EDA
#
# * Your project contains at least 4 meaningful data visualizations, with corresponding interpretations. All visualizations are well labeled with axes labels, a title, and a legend (when appropriate)
# * You pose at least 3 meaningful questions and answer them through EDA.  These questions should be well labeled and easy to identify inside the notebook.
#     * **Level Up**: Each question is clearly answered with a visualization that makes the answer easy to understand.
# * Your notebook should contain 1 - 2 paragraphs briefly explaining your approach to this project.
#
# ### Schedule
# - Wednesday, 6/17: Project kickoff
# - Thursday 6/18: Coach check-ins
# - Friday 6/19: Optional lead check-ins
# - Monday 6/22 morning: Presentations
#
# ## Grading Rubric
#
# This rubric is garbage, but if you'd like something to reference, use the top half of  [this](https://github.com/learn-co-curriculum/dsc-mod-1-project-v2-1/blob/master/module1_project_rubric.pdf).  Reminder: this is not actually being graded.
#
# ## Summary
#
# The end of module projects are a critical part of the program. They give you a chance to both bring together all the skills you've learned into realistic projects.
#
# The projects are serious and important. They are not graded, but feedback will be given. Take the project seriously, put the time in, ask for help from your peers or instructors early and often if you need it, and treat the review as a job interview and you'll do great. We're rooting for you to succeed and we're only going to ask you to take a review again if we believe that you need to. We'll also provide open and honest feedback so you can improve as quickly and efficiently as possible.

# %% [markdown]
# Questions:
# 1.

# %%
#import libraries and create connection
import pandas as pd
import mysql.connector
con = mysql.connector.connect(user='hbs-student', password='super-secure-password?',
                              host='hbs-ds-060120.c1doesqrid0e.us-east-1.rds.amazonaws.com',
                              database='movies')

# %%
#template to read tables
df_budget = pd.read_sql_query("""
SELECT *
FROM movies.tn_movie_budgets""", con)

# %%
df_budget
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
df_budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
def remove_dollar(value):
    return value.replace(',', '').replace('$', '')

# %%
df_budget['production_budget'] = df_budget['production_budget'].map(remove_dollar).astype(int).map(lambda x: round(x / 1000000))
df_budget['domestic_gross'] = df_budget['domestic_gross'].map(remove_dollar).astype(int).map(lambda x: round(x / 1000000))

# %%
df_budget.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross worldwide_gross
# 0                425             761  $2,776,345,279
# 1                411             241  $1,045,663,875
# 2                350              43    $149,762,350
# 3                331             459  $1,403,013,963
# 4                317             620  $1,316,721,747

# %%
def million(number):
    number_int = int(number)
    return round(number_int / 1000000)

# %%
df_budget['worldwide_gross'] = df_budget['worldwide_gross'].map(remove_dollar).map(million)

# %%
df_budget_renamed = df_budget.rename(columns={'production_budget':'production_budget_millions', 'domestic_gross': 'domestic_gross_millions', 'worldwide_gross': 'worldwide_gross_millions'})

# %%
df_budget_renamed
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget_millions  domestic_gross_millions  \
# 0                            425                      761
# 1                            411                      241
# 2                            350                       43
# 3                            331                      459
# 4                            317                      620
# ...                          ...                      ...
# 5777                           0                        0
# 5778                           0                        0
# 5779                           0                        0
# 5780                           0                        0
# 5781                           0                        0
#
#       worldwide_gross_millions
# 0                         2776
# 1                         1046
# 2                          150
# 3                         1403
# 4                         1317
# ...                        ...
# 5777                         0
# 5778                         0
# 5779                         0
# 5780                         0
# 5781                         0
#
# [5782 rows x 6 columns]

# %%
df_budget_renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          5782 non-null   int64
#  1   release_date                5782 non-null   object
#  2   movie                       5782 non-null   object
#  3   production_budget_millions  5782 non-null   int64
#  4   domestic_gross_millions     5782 non-null   int64
#  5   worldwide_gross_millions    5782 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 271.2+ KB

# %%
df_budget_renamed['total_revenue'] = df_budget_renamed['domestic_gross_millions'] + df_budget_renamed['worldwide_gross_millions']
df_budget_renamed
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget_millions  domestic_gross_millions  \
# 0                            425                      761
# 1                            411                      241
# 2                            350                       43
# 3                            331                      459
# 4                            317                      620
# ...                          ...                      ...
# 5777                           0                        0
# 5778                           0                        0
# 5779                           0                        0
# 5780                           0                        0
# 5781                           0                        0
#
#       worldwide_gross_millions  total_revenue
# 0                         2776           3537
# 1                         1046           1287
# 2                          150            193
# 3                         1403           1862
# 4                         1317           1937
# ...                        ...            ...
# 5777                         0              0
# 5778                         0              0
# 5779                         0              0
# 5780                         0              0
# 5781                         0              0
#
# [5782 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid')

sns.scatterplot(data=df_budget_renamed, x='production_budget_millions', y='total_revenue')

# %%
# creating similar graph based on the genre of movie
df_budget_genre = pd.read_sql_query("""
SELECT *
FROM movies.tn_movie_budgets
JOIN movies.imdb_title_basics
ON movies.tn_movie_budgets.movie = movies.imdb_title_basics.primary_title
""", con)

# %%
df_budget_genre
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      7  Apr 27, 2018                       Avengers: Infinity War
# ...   ..           ...                                          ...
# 3897  68   Jul 6, 2001                                         Cure
# 3898  70   Apr 1, 1996                                         Bang
# 3899  73  Jan 13, 2012                                    Newlyweds
# 3900  78  Dec 31, 2018                                       Red 11
# 3901  81  Sep 29, 2015                         A Plague So Pleasant
#
#      production_budget domestic_gross worldwide_gross     tconst  \
# 0         $425,000,000   $760,507,625  $2,776,345,279  tt1775309
# 1         $410,600,000   $241,063,875  $1,045,663,875  tt1298650
# 2         $350,000,000    $42,762,350    $149,762,350  tt6565702
# 3         $330,600,000   $459,005,868  $1,403,013,963  tt2395427
# 4         $300,000,000   $678,815,482  $2,048,134,200  tt4154756
# ...                ...            ...             ...        ...
# 3897           $10,000        $94,596         $94,596  tt5936960
# 3898           $10,000           $527            $527  tt6616538
# 3899            $9,000         $4,584          $4,584  tt1880418
# 3900            $7,000             $0              $0  tt7837402
# 3901            $1,400             $0              $0  tt2107644
#
#                                     primary_title  \
# 0                                          Avatar
# 1     Pirates of the Caribbean: On Stranger Tides
# 2                                    Dark Phoenix
# 3                         Avengers: Age of Ultron
# 4                          Avengers: Infinity War
# ...                                           ...
# 3897                                         Cure
# 3898                                         Bang
# 3899                                    Newlyweds
# 3900                                       Red 11
# 3901                         A Plague So Pleasant
#
#                                    original_title  start_year  \
# 0                                           Abatâ        2011
# 1     Pirates of the Caribbean: On Stranger Tides        2011
# 2                                    Dark Phoenix        2019
# 3                         Avengers: Age of Ultron        2015
# 4                          Avengers: Infinity War        2018
# ...                                           ...         ...
# 3897                                         Cure        2014
# 3898                                         Bang        2015
# 3899                                    Newlyweds        2011
# 3900                                       Red 11        2019
# 3901                         A Plague So Pleasant        2013
#
#       runtime_minutes                    genres
# 0                93.0                    Horror
# 1               136.0  Action,Adventure,Fantasy
# 2               113.0   Action,Adventure,Sci-Fi
# 3               141.0   Action,Adventure,Sci-Fi
# 4               149.0   Action,Adventure,Sci-Fi
# ...               ...                       ...
# 3897              NaN
# 3898              NaN
# 3899             95.0              Comedy,Drama
# 3900             77.0    Horror,Sci-Fi,Thriller
# 3901             76.0     Drama,Horror,Thriller
#
# [3902 rows x 12 columns]

# %%
df_budget_genre.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   7  Apr 27, 2018                       Avengers: Infinity War
#
#   production_budget domestic_gross worldwide_gross     tconst  \
# 0      $425,000,000   $760,507,625  $2,776,345,279  tt1775309
# 1      $410,600,000   $241,063,875  $1,045,663,875  tt1298650
# 2      $350,000,000    $42,762,350    $149,762,350  tt6565702
# 3      $330,600,000   $459,005,868  $1,403,013,963  tt2395427
# 4      $300,000,000   $678,815,482  $2,048,134,200  tt4154756
#
#                                  primary_title  \
# 0                                       Avatar
# 1  Pirates of the Caribbean: On Stranger Tides
# 2                                 Dark Phoenix
# 3                      Avengers: Age of Ultron
# 4                       Avengers: Infinity War
#
#                                 original_title  start_year  runtime_minutes  \
# 0                                        Abatâ        2011             93.0
# 1  Pirates of the Caribbean: On Stranger Tides        2011            136.0
# 2                                 Dark Phoenix        2019            113.0
# 3                      Avengers: Age of Ultron        2015            141.0
# 4                       Avengers: Infinity War        2018            149.0
#
#                      genres
# 0                    Horror
# 1  Action,Adventure,Fantasy
# 2   Action,Adventure,Sci-Fi
# 3   Action,Adventure,Sci-Fi
# 4   Action,Adventure,Sci-Fi

# %%
# we have lost a thousand rows by inner join by the name of the movie
df_budget_genre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3902 entries, 0 to 3901
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3902 non-null   int64
#  1   release_date       3902 non-null   object
#  2   movie              3902 non-null   object
#  3   production_budget  3902 non-null   object
#  4   domestic_gross     3902 non-null   object
#  5   worldwide_gross    3902 non-null   object
#  6   tconst             3902 non-null   object
#  7   primary_title      3902 non-null   object
#  8   original_title     3902 non-null   object
#  9   start_year         3902 non-null   int64
#  10  runtime_minutes    3404 non-null   float64
#  11  genres             3902 non-null   object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 365.9+ KB

# %%
df_budget_genre['release_date'] = pd.to_datetime(df_budget_genre['release_date'])

# %%
df_budget_genre['genres'] = df_budget_genre['genres'].map(lambda x: x.split(','))

# %%
df_budget_genre
# Out:
#       id release_date                                        movie  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      7   2018-04-27                       Avengers: Infinity War
# ...   ..          ...                                          ...
# 3897  68   2001-07-06                                         Cure
# 3898  70   1996-04-01                                         Bang
# 3899  73   2012-01-13                                    Newlyweds
# 3900  78   2018-12-31                                       Red 11
# 3901  81   2015-09-29                         A Plague So Pleasant
#
#      production_budget domestic_gross worldwide_gross     tconst  \
# 0         $425,000,000   $760,507,625  $2,776,345,279  tt1775309
# 1         $410,600,000   $241,063,875  $1,045,663,875  tt1298650
# 2         $350,000,000    $42,762,350    $149,762,350  tt6565702
# 3         $330,600,000   $459,005,868  $1,403,013,963  tt2395427
# 4         $300,000,000   $678,815,482  $2,048,134,200  tt4154756
# ...                ...            ...             ...        ...
# 3897           $10,000        $94,596         $94,596  tt5936960
# 3898           $10,000           $527            $527  tt6616538
# 3899            $9,000         $4,584          $4,584  tt1880418
# 3900            $7,000             $0              $0  tt7837402
# 3901            $1,400             $0              $0  tt2107644
#
#                                     primary_title  \
# 0                                          Avatar
# 1     Pirates of the Caribbean: On Stranger Tides
# 2                                    Dark Phoenix
# 3                         Avengers: Age of Ultron
# 4                          Avengers: Infinity War
# ...                                           ...
# 3897                                         Cure
# 3898                                         Bang
# 3899                                    Newlyweds
# 3900                                       Red 11
# 3901                         A Plague So Pleasant
#
#                                    original_title  start_year  \
# 0                                           Abatâ        2011
# 1     Pirates of the Caribbean: On Stranger Tides        2011
# 2                                    Dark Phoenix        2019
# 3                         Avengers: Age of Ultron        2015
# 4                          Avengers: Infinity War        2018
# ...                                           ...         ...
# 3897                                         Cure        2014
# 3898                                         Bang        2015
# 3899                                    Newlyweds        2011
# 3900                                       Red 11        2019
# 3901                         A Plague So Pleasant        2013
#
#       runtime_minutes                        genres
# 0                93.0                      [Horror]
# 1               136.0  [Action, Adventure, Fantasy]
# 2               113.0   [Action, Adventure, Sci-Fi]
# 3               141.0   [Action, Adventure, Sci-Fi]
# 4               149.0   [Action, Adventure, Sci-Fi]
# ...               ...                           ...
# 3897              NaN                            []
# 3898              NaN                            []
# 3899             95.0               [Comedy, Drama]
# 3900             77.0    [Horror, Sci-Fi, Thriller]
# 3901             76.0     [Drama, Horror, Thriller]
#
# [3902 rows x 12 columns]

# %%
import collections
import itertools

genres = []
for number in range(len(df_budget_genre)):
    genre = df_budget_genre.iloc[number, 11]
    genres.append(genre)

genres = list(itertools.chain.from_iterable(genres))
c = collections.Counter(genres)
topten_genres_separated = list(c.keys())[:10]

# %%
topten_genres_separated
# Out:
# ['Horror',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Sci-Fi',
#  'Thriller',
#  'Western',
#  'Animation',
#  'Comedy',
#  'Family']

# %%
for genre in topten_genres_separated:
    df_bygenre = df.loc[df['genres'] == genre]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-ea6039dbb3cd> in <module>
#       1 for genre in topten_genres_separated:
# ----> 2     df_bygenre = df.loc[df['genres'] == genre]
#
# NameError: name 'df' is not defined

# %%
df_budget_genre.loc[df_budget_genre['genres'].isin(['Action'])]

# %%
def includes(genre):
    if genre is in 

    
df_bygenre[genr

# %%
# creating similar graph based on the genre of movie
df_budget_genre2 = pd.read_sql_query("""
SELECT *
FROM movies.tn_movie_budgets
JOIN movies.imdb_title_basics
ON movies.tn_movie_budgets.movie = movies.imdb_title_basics.primary_title
""", con)

# %%
df_budget_genre2[df_budget_genre2['genres'].str.contains('Action')]

# %%
df_budget_genre.info()i

# %%
df_budget_genre.genres.value_counts().head(11)

# %% [markdown]
# #Top 10 genre
# Drama                         512
# Documentary                   295
# Comedy                        144
# Comedy,Drama                  106
# Horror                         95
# Drama,Romance                  91
# Comedy,Drama,Romance           86
# Thriller                       83
# Adventure,Animation,Comedy     75

# %%
topten_genre = ['Drama', 'Documentary', 'Comedy', 'Comedy,Drama', 'Horror', 'Drama,Romance', 'Comedy,Drama,Romance', 'Thriller', 'Adventure,Animation,Comedy', 'Drama,Thriller']

# %%
#working
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set(style='darkgrid')

for genre in topten_genre:
    # filter by genre
    df_budget_genre_analysis2 = df_budget_genre.loc[df_budget_genre['genres'] == genre]

    # change type to int and change unit to $MM
    df_budget_genre_analysis2['production_budget'] = df_budget_genre_analysis2['production_budget'].map(remove_dollar).astype(int).map(lambda x: round(x / 1000000))
    df_budget_genre_analysis2['domestic_gross'] = df_budget_genre_analysis2['domestic_gross'].map(remove_dollar).astype(int).map(lambda x: round(x / 1000000))
    df_budget_genre_analysis2['worldwide_gross'] = df_budget_genre_analysis2['worldwide_gross'].map(remove_dollar).map(million)
    df_budget_genre_analysis2['total_revenue'] = df_budget_genre_analysis2['domestic_gross'] + df_budget_genre_analysis2['worldwide_gross']
    
    plt.figure()
    plt.title(genre)
    sns.regplot(data=df_budget_genre_analysis2, x='production_budget', y='total_revenue')
    
    print(genre)
    print(np.corrcoef(df_budget_genre_analysis2['production_budget'], df_budget_genre_analysis2['total_revenue']))

# %%
# 2nd analysis: is there a correlation between rating website? if not, which is more correalted with sales

# %%
df2 = pd.read_sql_query("""
SELECT *
FROM rt_movie_info
""", con)

# %%
df2.head()

# %%
def minutes_conversion(value):
    number, unit = value.split(' ')
    number = int(number)
    return number

# %%
df2['runtime'] = df2['runtime'].map(minutes_conversion)

# %%
# runtime vs sales, 一定以上のROIを上げている映画とそれ以外の映画でRuntimeに違いはあるか。

# %%
# creating similar graph based on the genre of movie
df_budget_genre_rating = pd.read_sql_query("""
SELECT *
FROM movies.tn_movie_budgets
JOIN movies.imdb_title_basics
ON movies.tn_movie_budgets.movie = movies.imdb_title_basics.primary_title
JOIN movies.imdb_title_ratings
USING(tconst)
ORDER BY movies.imdb_title_ratings.averagerating DESC
""", con)

# %%
df_budget_genre_rating.head(10)
# Out:
#       tconst  id  release_date         movie production_budget domestic_gross  \
# 0  tt8106586  86  Jun 23, 2015    Crossroads          $500,000             $0
# 1  tt8106586  67  Feb 15, 2002    Crossroads       $12,000,000    $37,188,667
# 2  tt1455256  29  May 12, 2017      The Wall        $3,000,000     $1,803,064
# 3  tt4061640  16  Dec 27, 2000       Traffic       $48,000,000   $124,107,476
# 4  tt6168914  57  Mar 19, 2010  The Runaways        $9,500,000     $3,573,673
# 5  tt8680254  65  Dec 29, 1995   Richard III        $9,200,000     $2,684,904
# 6  tt1795369   3   Nov 4, 1994  Frankenstein       $45,000,000    $22,006,296
# 7  tt2215463  11  May 29, 2015      Survivor       $20,000,000             $0
# 8  tt2316649  95  Apr 12, 2002       Frailty       $11,000,000    $13,110,448
# 9  tt3060772  28  Feb 22, 2002     Dragonfly       $60,000,000    $30,063,805
#
#   worldwide_gross primary_title                       original_title  \
# 0              $0    Crossroads                           Crossroads
# 1     $57,000,000    Crossroads                           Crossroads
# 2      $4,495,262      The Wall                             The Wall
# 3    $208,300,000       Traffic                              Traffic
# 4      $5,278,632  The Runaways                         The Runaways
# 5      $4,199,334   Richard III                          Richard III
# 6    $112,006,296  Frankenstein  National Theatre Live: Frankenstein
# 7      $1,703,281      Survivor                             Survivor
# 8     $19,947,280       Frailty                              Frailty
# 9     $30,063,805     Dragonfly                            Dragonfly
#
#    start_year  runtime_minutes                       genres  averagerating  \
# 0        2018              NaN                  Documentary            9.3
# 1        2018              NaN                  Documentary            9.3
# 2        2010             78.0                  Documentary            9.2
# 3        2014            110.0                  Documentary            9.2
# 4        2019            108.0                    Adventure            9.2
# 5        2016              NaN                        Drama            9.1
# 6        2011            130.0                        Drama            9.0
# 7        2012             81.0  Biography,Crime,Documentary            9.0
# 8        2012              NaN                        Drama            9.0
# 9        2013             75.0      Action,Adventure,Sci-Fi            9.0
#
#    numvotes
# 0        22
# 1        22
# 2         8
# 3        64
# 4        47
# 5        28
# 6      1832
# 7        45
# 8        13
# 9         5

# %%
df_budget_genre_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2943 entries, 0 to 2942
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             2943 non-null   object
#  1   id                 2943 non-null   int64
#  2   release_date       2943 non-null   object
#  3   movie              2943 non-null   object
#  4   production_budget  2943 non-null   object
#  5   domestic_gross     2943 non-null   object
#  6   worldwide_gross    2943 non-null   object
#  7   primary_title      2943 non-null   object
#  8   original_title     2943 non-null   object
#  9   start_year         2943 non-null   int64
#  10  runtime_minutes    2822 non-null   float64
#  11  genres             2943 non-null   object
#  12  averagerating      2943 non-null   float64
#  13  numvotes           2943 non-null   int64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 322.0+ KB

# %%
df_budget_genre_rating.describe()
# Out:
#                 id   start_year  runtime_minutes  averagerating      numvotes
# count  2943.000000  2943.000000      2822.000000    2943.000000  2.943000e+03
# mean     51.018349  2013.930683       102.963855       6.250085  6.611289e+04
# std      28.655002     2.558351        20.734837       1.183322  1.335039e+05
# min       1.000000  2010.000000         3.000000       1.600000  5.000000e+00
# 25%      27.000000  2012.000000        90.000000       5.600000  1.440000e+02
# 50%      51.000000  2014.000000       101.000000       6.400000  7.999000e+03
# 75%      76.000000  2016.000000       113.000000       7.100000  7.497850e+04
# max     100.000000  2019.000000       280.000000       9.300000  1.841066e+06

# %%
df_budget_genre_rating = df_budget_genre_rating[df_budget_genre_rating['numvotes']>=8000]

# %%
x = [[1.         0.66314272][0.66314272 1.        ]]
# Out:
#   File "<ipython-input-132-dd84150090c2>", line 1
#     x = [[1.         0.66314272][0.66314272 1.        ]]
#                               ^
# SyntaxError: invalid syntax

# %%
df_budget_genre_rating.head()
# Out:
#        tconst  id  release_date                   movie production_budget  \
# 16  tt1375666  38  Jul 16, 2010               Inception      $160,000,000
# 35  tt0816692  32   Nov 5, 2014            Interstellar      $165,000,000
# 39  tt4154756   7  Apr 27, 2018  Avengers: Infinity War      $300,000,000
# 40  tt0770802  18  Aug 24, 2012                 Samsara        $4,000,000
# 43  tt5074352  56  Dec 21, 2016                  Dangal        $9,500,000
#
#    domestic_gross worldwide_gross           primary_title  \
# 16   $292,576,195    $835,524,642               Inception
# 35   $188,017,894    $666,379,375            Interstellar
# 39   $678,815,482  $2,048,134,200  Avengers: Infinity War
# 40     $2,672,413      $5,966,671                 Samsara
# 43    $12,391,761    $294,654,618                  Dangal
#
#             original_title  start_year  runtime_minutes  \
# 16               Inception        2010            148.0
# 35            Interstellar        2014            169.0
# 39  Avengers: Infinity War        2018            149.0
# 40                 Samsara        2011            102.0
# 43                  Dangal        2016            161.0
#
#                      genres  averagerating  numvotes
# 16  Action,Adventure,Sci-Fi            8.8   1841066
# 35   Adventure,Drama,Sci-Fi            8.6   1299334
# 39  Action,Adventure,Sci-Fi            8.5    670926
# 40        Documentary,Music            8.5     29725
# 43   Action,Biography,Drama            8.5    123638

# %%
df_budget_genre_rating['production_budget'] = df_budget_genre_rating['production_budget'].map(remove_dollar).astype(int).map(lambda x: round(x / 1000000))
df_budget_genre_rating['domestic_gross'] = df_budget_genre_rating['domestic_gross'].map(remove_dollar).astype(int).map(lambda x: round(x / 1000000))
df_budget_genre_rating['worldwide_gross'] = df_budget_genre_rating['worldwide_gross'].map(remove_dollar).map(million)
df_budget_genre_rating['total_revenue'] = df_budget_genre_rating['domestic_gross'] + df_budget_genre_rating['worldwide_gross']

# %%
df_budget_genre_rating.head()
# Out:
#        tconst  id  release_date                   movie  production_budget  \
# 16  tt1375666  38  Jul 16, 2010               Inception                160
# 35  tt0816692  32   Nov 5, 2014            Interstellar                165
# 39  tt4154756   7  Apr 27, 2018  Avengers: Infinity War                300
# 40  tt0770802  18  Aug 24, 2012                 Samsara                  4
# 43  tt5074352  56  Dec 21, 2016                  Dangal                 10
#
#     domestic_gross  worldwide_gross           primary_title  \
# 16             293              836               Inception
# 35             188              666            Interstellar
# 39             679             2048  Avengers: Infinity War
# 40               3                6                 Samsara
# 43              12              295                  Dangal
#
#             original_title  start_year  runtime_minutes  \
# 16               Inception        2010            148.0
# 35            Interstellar        2014            169.0
# 39  Avengers: Infinity War        2018            149.0
# 40                 Samsara        2011            102.0
# 43                  Dangal        2016            161.0
#
#                      genres  averagerating  numvotes  total_revenue
# 16  Action,Adventure,Sci-Fi            8.8   1841066           1129
# 35   Adventure,Drama,Sci-Fi            8.6   1299334            854
# 39  Action,Adventure,Sci-Fi            8.5    670926           2727
# 40        Documentary,Music            8.5     29725              9
# 43   Action,Biography,Drama            8.5    123638            307

# %%
# budget vs runtime
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid')

plt.title('budget vs runtime')
sns.regplot(data=df_budget_genre_rating, x='production_budget', y='runtime_minutes')
np.corrcoef(df_budget_genre_rating['production_budget'], df_budget_genre_rating['runtime_minutes'])
# Out:
# array([[1.        , 0.33925108],
#        [0.33925108, 1.        ]])

# %%
# runtime vs rating
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid')

plt.title('runtime vs rating')
sns.regplot(data=df_budget_genre_rating, x='runtime_minutes', y='averagerating')
np.corrcoef(df_budget_genre_rating['runtime_minutes'], df_budget_genre_rating['averagerating'])
# Out:
# array([[1.        , 0.41683967],
#        [0.41683967, 1.        ]])

# %%
df_budget_genre_rating.genres.unique()
# Out:
# array(['Action,Adventure,Sci-Fi', 'Adventure,Drama,Sci-Fi',
#        'Documentary,Music', 'Action,Biography,Drama', 'Drama,Music',
#        'Action,Thriller', 'Adventure,Animation,Comedy', 'Drama,Western',
#        'Crime,Documentary', 'Action,Drama', 'Biography,Comedy,Drama',
#        'Drama,Mystery,War', 'Crime,Drama', 'Biography,Crime,Drama',
#        'Drama,Thriller', 'Drama,Sport', 'Action,Drama,Sci-Fi', 'Drama',
#        'Biography,Drama', 'Action,Adventure,Comedy',
#        'Drama,Mystery,Thriller', 'Mystery,Thriller',
#        'Crime,Drama,Mystery', 'Adventure,Comedy,Crime',
#        'Action,Adventure,Animation', 'Biography,Drama,History',
#        'Biography,Drama,Music', 'Drama,Mystery,Sci-Fi',
#        'Comedy,Drama,Music', 'Drama,Family', 'Biography,Drama,Thriller',
#        'Action,Comedy,Drama', 'Action,Adventure,Biography',
#        'Drama,Romance,Sci-Fi', 'Action,Drama,History',
#        'Documentary,Sport,Thriller', 'Drama,Romance', 'Action,Sci-Fi',
#        'Adventure,Drama,Fantasy', 'Comedy,Drama,Romance',
#        'Adventure,Comedy,Drama', 'Crime,Drama,Thriller',
#        'Adventure,Family,Fantasy', 'Comedy,Drama,Fantasy',
#        'Adventure,Fantasy', 'Documentary', 'Drama,Music,Romance',
#        'Action,Adventure,Thriller', 'Biography,Drama,Sport',
#        'Adventure,Animation,Drama', 'Documentary,Drama',
#        'Crime,Drama,Romance', 'Horror,Mystery,Thriller', 'Comedy,Drama',
#        'Comedy,Fantasy,Romance', 'Biography,Drama,Romance',
#        'Drama,Sci-Fi,Thriller', 'Animation,Comedy,Family',
#        'Biography,Drama,Musical', 'Drama,History,Thriller',
#        'Action,Crime,Drama', 'Action,Comedy', 'Adventure,Drama,Western',
#        'Action,Adventure,Drama', 'Action,Drama,War',
#        'Drama,Horror,Sci-Fi', 'Action,Sci-Fi,Thriller', 'Drama,War',
#        'Adventure,Biography,Drama', 'Drama,History,Musical',
#        'Adventure,Drama,Family', 'Animation,Drama,Fantasy',
#        'Action,Adventure,Fantasy', 'Animation,Drama',
#        'Action,Adventure,Crime', 'Action,Comedy,Fantasy',
#        'Drama,History,War', 'Horror,Thriller', 'Mystery,Sci-Fi,Thriller',
#        'Biography,Drama,Family', 'Action,Comedy,Crime',
#        'Action,Crime,Thriller', 'Adventure,Comedy,Family',
#        'Drama,Horror,Thriller', 'Biography,Drama,Mystery',
#        'Action,Drama,Mystery', 'Crime,Mystery,Thriller',
#        'Comedy,Crime,Thriller', 'Drama,Thriller,War',
#        'Animation,Comedy,Drama', 'Action,Animation,Comedy',
#        'Comedy,Crime,Drama', 'Drama,Horror,Mystery', 'Drama,Sci-Fi',
#        'Family,Fantasy,Musical', 'Biography,Comedy,Crime',
#        'Drama,Fantasy,Romance', 'Action,Biography,Comedy', 'Comedy,Crime',
#        'Drama,Mystery', 'Comedy,Romance', 'Music',
#        'Adventure,Drama,History', 'Comedy,Music,Romance',
#        'Adventure,Crime,Drama', 'Adventure,Drama', 'Comedy,Drama,Family',
#        'Drama,Fantasy,Horror', 'Action,Drama,Romance',
#        'Adventure,Drama,Horror', 'Drama,Fantasy', 'Action,Drama,Family',
#        'Romance,Sci-Fi,Thriller', 'Comedy,Drama,Musical',
#        'Action,Drama,Sport', 'Drama,Mystery,Romance',
#        'Action,Crime,Sci-Fi', 'Adventure,Mystery,Sci-Fi',
#        'Adventure,Comedy,Sci-Fi', 'Comedy,Fantasy,Sci-Fi',
#        'Adventure,Drama,Romance', 'Action,Mystery,Thriller',
#        'Horror,Music,Thriller', 'Action,Adventure,Horror',
#        'Action,Adventure,Family', 'Horror', 'Action,Comedy,Documentary',
#        'Action,Comedy,Sci-Fi', 'Comedy,Horror,Romance',
#        'Crime,Drama,History', 'Sci-Fi,Thriller', 'Drama,Family,Fantasy',
#        'Horror,Mystery', 'Action,Adventure,Western', 'Comedy,Fantasy',
#        'Comedy,Family,Fantasy', 'Comedy,Horror,Mystery',
#        'Action,Biography,Crime', 'Action,Mystery,Sci-Fi',
#        'Adventure,Drama,Thriller', 'Drama,Fantasy,Music',
#        'Fantasy,Horror,Mystery', 'Drama,Horror', 'Action,Drama,Thriller',
#        'Crime,Drama,Horror', 'Adventure,Animation,Family', 'Comedy,Music',
#        'Drama,Family,Sport', 'Comedy', 'Action,Crime,Mystery',
#        'Action,Adventure,Mystery', 'Drama,Romance,Thriller',
#        'Comedy,Family', 'Action,Comedy,Horror', 'Horror,Sci-Fi,Thriller',
#        'Action,Fantasy,Horror', 'Fantasy,Horror,Thriller',
#        'Adventure,Comedy', 'Biography,Drama,War', 'Crime,Thriller',
#        'Comedy,Mystery', 'Horror,Sci-Fi', 'Action,Horror,Sci-Fi',
#        'Comedy,Drama,Sport', 'Comedy,Fantasy,Thriller', 'Comedy,Horror',
#        'Action,Crime,Fantasy', 'Adventure,Comedy,Fantasy',
#        'Comedy,Sci-Fi', 'Drama,Music,Musical', 'Drama,History,Mystery',
#        'Drama,Fantasy,Mystery', 'Action,Comedy,Sport',
#        'Adventure,Comedy,Music', 'Comedy,Drama,Mystery',
#        'Comedy,Crime,Romance', 'Drama,Romance,War',
#        'Action,Drama,Fantasy', 'Action,Fantasy,Western',
#        'Adventure,Biography,Comedy', 'Action,Comedy,Romance',
#        'Action,Drama,Western', 'Comedy,Horror,Sci-Fi',
#        'Adventure,Crime,Thriller', 'Action,Fantasy,War',
#        'Comedy,Fantasy,Horror', 'Action,Crime,Horror',
#        'Adventure,Horror,Mystery', 'Drama,History,Romance',
#        'Adventure,Drama,Sport', 'Horror,Mystery,Sci-Fi', 'Drama,History',
#        'Action,Horror,Thriller', 'Comedy,Western', 'Comedy,Drama,History',
#        'Adventure,Comedy,Romance', 'Comedy,Documentary',
#        'Comedy,Romance,Sport', 'Crime,Horror,Mystery',
#        'Adventure,Family,Sci-Fi', 'Action,Adventure,Romance',
#        'Comedy,Family,Romance', 'Comedy,Sport', 'Action,Crime',
#        'Comedy,Music,War', 'Adventure,Horror,Sci-Fi',
#        'Action,Comedy,Family', 'Action,Fantasy,Thriller', 'Action',
#        'Biography,Drama,Fantasy', 'Adventure,Horror',
#        'Action,Crime,Sport', 'Comedy,Drama,Horror',
#        'Comedy,Mystery,Sci-Fi'], dtype=object)

# %%
df_budget_genre.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   7   2018-04-27                       Avengers: Infinity War
#
#   production_budget domestic_gross worldwide_gross     tconst  \
# 0      $425,000,000   $760,507,625  $2,776,345,279  tt1775309
# 1      $410,600,000   $241,063,875  $1,045,663,875  tt1298650
# 2      $350,000,000    $42,762,350    $149,762,350  tt6565702
# 3      $330,600,000   $459,005,868  $1,403,013,963  tt2395427
# 4      $300,000,000   $678,815,482  $2,048,134,200  tt4154756
#
#                                  primary_title  \
# 0                                       Avatar
# 1  Pirates of the Caribbean: On Stranger Tides
# 2                                 Dark Phoenix
# 3                      Avengers: Age of Ultron
# 4                       Avengers: Infinity War
#
#                                 original_title  start_year  runtime_minutes  \
# 0                                        Abatâ        2011             93.0
# 1  Pirates of the Caribbean: On Stranger Tides        2011            136.0
# 2                                 Dark Phoenix        2019            113.0
# 3                      Avengers: Age of Ultron        2015            141.0
# 4                       Avengers: Infinity War        2018            149.0
#
#                          genres
# 0                      [Horror]
# 1  [Action, Adventure, Fantasy]
# 2   [Action, Adventure, Sci-Fi]
# 3   [Action, Adventure, Sci-Fi]
# 4   [Action, Adventure, Sci-Fi]

# %%
df_budget_genre['year'] = df_budget_genre['release_date'].map(lambda x: x.year)

# %%
df_budget_genre2 = df_budget_genre

# %%
df_budget_genre2.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   7   2018-04-27                       Avengers: Infinity War
#
#   production_budget domestic_gross worldwide_gross     tconst  \
# 0      $425,000,000   $760,507,625  $2,776,345,279  tt1775309
# 1      $410,600,000   $241,063,875  $1,045,663,875  tt1298650
# 2      $350,000,000    $42,762,350    $149,762,350  tt6565702
# 3      $330,600,000   $459,005,868  $1,403,013,963  tt2395427
# 4      $300,000,000   $678,815,482  $2,048,134,200  tt4154756
#
#                                  primary_title  \
# 0                                       Avatar
# 1  Pirates of the Caribbean: On Stranger Tides
# 2                                 Dark Phoenix
# 3                      Avengers: Age of Ultron
# 4                       Avengers: Infinity War
#
#                                 original_title  start_year  runtime_minutes  \
# 0                                        Abatâ        2011             93.0
# 1  Pirates of the Caribbean: On Stranger Tides        2011            136.0
# 2                                 Dark Phoenix        2019            113.0
# 3                      Avengers: Age of Ultron        2015            141.0
# 4                       Avengers: Infinity War        2018            149.0
#
#                          genres  year
# 0                      [Horror]  2009
# 1  [Action, Adventure, Fantasy]  2011
# 2   [Action, Adventure, Sci-Fi]  2019
# 3   [Action, Adventure, Sci-Fi]  2015
# 4   [Action, Adventure, Sci-Fi]  2018

# %%
df_budget_genre2['production_budget'] = df_budget_genre2['production_budget'].map(remove_dollar).astype(int).map(lambda x: round(x / 1000000))
df_budget_genre2['domestic_gross'] = df_budget_genre2['domestic_gross'].map(remove_dollar).astype(int).map(lambda x: round(x / 1000000))
df_budget_genre2['worldwide_gross'] = df_budget_genre2['worldwide_gross'].map(remove_dollar).map(million)
df_budget_genre2['total_revenue'] = df_budget_genre2['domestic_gross'] + df_budget_genre2['worldwide_gross']

# %%
df_budget_genre2['ROI'] = df_budget_genre2['total_revenue'] / df_budget_genre2['production_budget']

# %%
df_budget_genre2.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   7   2018-04-27                       Avengers: Infinity War
#
#    production_budget  domestic_gross  worldwide_gross     tconst  \
# 0                425             761             2776  tt1775309
# 1                411             241             1046  tt1298650
# 2                350              43              150  tt6565702
# 3                331             459             1403  tt2395427
# 4                300             679             2048  tt4154756
#
#                                  primary_title  \
# 0                                       Avatar
# 1  Pirates of the Caribbean: On Stranger Tides
# 2                                 Dark Phoenix
# 3                      Avengers: Age of Ultron
# 4                       Avengers: Infinity War
#
#                                 original_title  start_year  runtime_minutes  \
# 0                                        Abatâ        2011             93.0
# 1  Pirates of the Caribbean: On Stranger Tides        2011            136.0
# 2                                 Dark Phoenix        2019            113.0
# 3                      Avengers: Age of Ultron        2015            141.0
# 4                       Avengers: Infinity War        2018            149.0
#
#                          genres  year  total_revenue       ROI
# 0                      [Horror]  2009           3537  8.322353
# 1  [Action, Adventure, Fantasy]  2011           1287  3.131387
# 2   [Action, Adventure, Sci-Fi]  2019            193  0.551429
# 3   [Action, Adventure, Sci-Fi]  2015           1862  5.625378
# 4   [Action, Adventure, Sci-Fi]  2018           2727  9.090000

# %%
df_new_horror = df_budget_genre2[df_budget_genre2['genres'].str.contains('Horror')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-146-66cf3d922f84> in <module>
# ----> 1 df_new_horror = df_budget_genre2[df_budget_genre2['genres'].str.contains('Horror')]
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Float64Index([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,\n              ...\n              nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],\n             dtype='float64', length=3902)] are in the [columns]"

# %%
df_new_horror_ROI = pd.DataFrame(df_new_horror.groupby('year').mean()['ROI'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-147-46666ff4ecc3> in <module>
# ----> 1 df_new_horror_ROI = pd.DataFrame(df_new_horror.groupby('year').mean()['ROI'])
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# C:\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     407                 sort=sort,
#     408                 observed=observed,
# --> 409                 mutated=self.mutated,
#     410             )
#     411
#
# C:\Anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     596                 in_axis, name, level, gpr = False, None, gpr, None
#     597             else:
# --> 598                 raise KeyError(gpr)
#     599         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     600             # Add key to exclusions
#
# KeyError: 'year'

# %%
df_new_horror_ROI = df_new_horror_ROI.reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-148-ba460944f188> in <module>
# ----> 1 df_new_horror_ROI = df_new_horror_ROI.reset_index()
#
# NameError: name 'df_new_horror_ROI' is not defined

# %%
df_new_horror_ROI.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-149-c1f4130da94d> in <module>
# ----> 1 df_new_horror_ROI.tail()
#
# NameError: name 'df_new_horror_ROI' is not defined

# %%
df_new_horror_RO_after = df_new_horror_ROI[df_new_horror_ROI['year']>= 2000]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-150-55ed0e4249f3> in <module>
# ----> 1 df_new_horror_RO_after = df_new_horror_ROI[df_new_horror_ROI['year']>= 2000]
#
# NameError: name 'df_new_horror_ROI' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid')

plt.title('ROI of horror movie')
sns.lineplot(data=df_new_horror_RO_after, x='year', y='ROI')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-151-9686d206c5d3> in <module>
#       4
#       5 plt.title('ROI of horror movie')
# ----> 6 sns.lineplot(data=df_new_horror_RO_after, x='year', y='ROI')
#
# NameError: name 'df_new_horror_RO_after' is not defined

# %%
df_test = df_budget_genre

# %%
df_test.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   7   2018-04-27                       Avengers: Infinity War
#
#   production_budget domestic_gross worldwide_gross     tconst  \
# 0      $425,000,000   $760,507,625  $2,776,345,279  tt1775309
# 1      $410,600,000   $241,063,875  $1,045,663,875  tt1298650
# 2      $350,000,000    $42,762,350    $149,762,350  tt6565702
# 3      $330,600,000   $459,005,868  $1,403,013,963  tt2395427
# 4      $300,000,000   $678,815,482  $2,048,134,200  tt4154756
#
#                                  primary_title  \
# 0                                       Avatar
# 1  Pirates of the Caribbean: On Stranger Tides
# 2                                 Dark Phoenix
# 3                      Avengers: Age of Ultron
# 4                       Avengers: Infinity War
#
#                                 original_title  start_year  runtime_minutes  \
# 0                                        Abatâ        2011             93.0
# 1  Pirates of the Caribbean: On Stranger Tides        2011            136.0
# 2                                 Dark Phoenix        2019            113.0
# 3                      Avengers: Age of Ultron        2015            141.0
# 4                       Avengers: Infinity War        2018            149.0
#
#                      genres
# 0                    Horror
# 1  Action,Adventure,Fantasy
# 2   Action,Adventure,Sci-Fi
# 3   Action,Adventure,Sci-Fi
# 4   Action,Adventure,Sci-Fi

# %%
df_test.iloc[0, 11]
# Out:
# 'Horror'

# %%
df_test.genres = df_test.genres.str.split(',')
genre_list = []
for x in range(len(df_test)):
    if df_test.iloc[x, 11] not in genre_list:
        genre_list.append(df_test.iloc[x, 11])

# %%
genre_list
# Out:
# [['Horror'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Action', 'Thriller'],
#  ['Action', 'Adventure', 'Western'],
#  ['Adventure', 'Animation', 'Comedy'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Adventure', 'Fantasy'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Action', 'Drama'],
#  [''],
#  ['Action', 'Adventure', 'History'],
#  ['Action', 'Adventure'],
#  ['Adventure'],
#  ['Family'],
#  ['Action', 'Adventure', 'Animation'],
#  ['Documentary'],
#  ['Fantasy', 'Musical'],
#  ['Action', 'Adventure', 'Horror'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Drama'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Adventure', 'Comedy', 'Family'],
#  ['Fantasy'],
#  ['Action', 'Adventure', 'Family'],
#  ['Adventure', 'Drama', 'Family'],
#  ['Action', 'Horror', 'Sci-Fi'],
#  ['Action', 'Sci-Fi'],
#  ['Animation'],
#  ['Crime', 'Drama'],
#  ['Biography', 'Documentary', 'History'],
#  ['Adventure', 'Drama', 'Sci-Fi'],
#  ['Drama', 'Fantasy', 'Romance'],
#  ['Family', 'Fantasy', 'Musical'],
#  ['Action', 'Drama', 'History'],
#  ['Sci-Fi'],
#  ['Documentary', 'Drama', 'Sport'],
#  ['Adventure', 'Drama', 'Sport'],
#  ['Fantasy', 'Romance'],
#  ['Action', 'Drama', 'Fantasy'],
#  ['Comedy', 'Fantasy', 'Horror'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Drama', 'Fantasy', 'Horror'],
#  ['Adventure', 'Animation', 'Family'],
#  ['Adventure', 'Animation', 'Drama'],
#  ['Action', 'Comedy', 'Fantasy'],
#  ['Action', 'Comedy'],
#  ['Action', 'Adventure', 'Biography'],
#  ['Thriller'],
#  ['Documentary', 'Drama', 'Family'],
#  ['Drama', 'Horror', 'Thriller'],
#  ['Biography', 'Documentary'],
#  ['Documentary', 'History'],
#  ['Documentary', 'Family'],
#  ['Animation', 'Documentary'],
#  ['Drama', 'Romance', 'Thriller'],
#  ['Drama', 'Family'],
#  ['Action', 'History', 'War'],
#  ['Comedy', 'Family', 'Fantasy'],
#  ['Action', 'Animation', 'Comedy'],
#  ['Action', 'Mystery', 'Thriller'],
#  ['Drama', 'Thriller'],
#  ['Animation', 'Documentary', 'Family'],
#  ['Action', 'Drama', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Crime'],
#  ['Adventure', 'Mystery', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Mystery'],
#  ['Action'],
#  ['Adventure', 'Drama', 'Fantasy'],
#  ['Action', 'Crime', 'Sci-Fi'],
#  ['Documentary', 'News'],
#  ['Documentary', 'Drama'],
#  ['Comedy'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Sci-Fi', 'Thriller'],
#  ['Drama', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Fantasy', 'War'],
#  ['Drama', 'Romance', 'Sci-Fi'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Action', 'Drama', 'Family'],
#  ['Adventure', 'Sport'],
#  ['Action', 'Drama', 'Romance'],
#  ['Documentary', 'Thriller'],
#  ['Action', 'Drama', 'Mystery'],
#  ['Drama', 'Western'],
#  ['Comedy', 'Romance'],
#  ['Biography', 'Crime', 'Drama'],
#  ['Comedy', 'Documentary', 'Drama'],
#  ['Action', 'Crime', 'Sport'],
#  ['Horror', 'Sci-Fi', 'Thriller'],
#  ['Musical'],
#  ['Comedy', 'Fantasy'],
#  ['Drama', 'Family', 'Fantasy'],
#  ['Music'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Crime'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Action', 'Comedy', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Romance'],
#  ['Drama', 'History'],
#  ['Action', 'Family', 'Fantasy'],
#  ['Action', 'Crime', 'Fantasy'],
#  ['Adventure', 'Drama'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Action', 'Comedy', 'Family'],
#  ['Drama', 'Fantasy', 'Musical'],
#  ['Documentary', 'Sport'],
#  ['Action', 'Comedy', 'Horror'],
#  ['Biography', 'Drama', 'Musical'],
#  ['Drama', 'Horror', 'Mystery'],
#  ['Biography', 'Documentary', 'Drama'],
#  ['Comedy', 'Mystery'],
#  ['Mystery', 'Thriller'],
#  ['Action', 'Drama', 'War'],
#  ['Comedy', 'Family', 'Romance'],
#  ['Horror', 'Thriller'],
#  ['Crime', 'Horror', 'Thriller'],
#  ['Romance'],
#  ['Crime', 'Mystery', 'Thriller'],
#  ['Biography', 'Drama'],
#  ['Action', 'Comedy', 'Romance'],
#  ['Action', 'Crime', 'Drama'],
#  ['Comedy', 'Drama', 'History'],
#  ['Mystery', 'Sci-Fi', 'Thriller'],
#  ['Crime'],
#  ['Adventure', 'Biography', 'Documentary'],
#  ['Biography', 'Drama', 'Thriller'],
#  ['Drama', 'History', 'War'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama', 'Horror'],
#  ['Action', 'Thriller', 'War'],
#  ['Action', 'Mystery', 'Sci-Fi'],
#  ['Action', 'Animation', 'Fantasy'],
#  ['Comedy', 'Drama', 'Musical'],
#  ['Action', 'Crime', 'Mystery'],
#  ['Crime', 'Documentary', 'Drama'],
#  ['Drama', 'Sci-Fi'],
#  ['Action', 'Fantasy', 'Horror'],
#  ['Biography', 'Crime', 'Documentary'],
#  ['War'],
#  ['Comedy', 'Romance', 'Sci-Fi'],
#  ['Biography', 'Drama', 'History'],
#  ['Crime', 'Drama', 'Family'],
#  ['Drama', 'History', 'Musical'],
#  ['Biography', 'Drama', 'Sport'],
#  ['Adventure', 'Comedy'],
#  ['Comedy', 'Musical'],
#  ['Biography', 'Drama', 'Western'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Mystery'],
#  ['Biography', 'Drama', 'Romance'],
#  ['Crime', 'Thriller'],
#  ['Biography', 'Comedy', 'Drama'],
#  ['Action', 'Romance'],
#  ['Drama', 'Sport'],
#  ['Comedy', 'Western'],
#  ['Action', 'Biography', 'Drama'],
#  ['Action', 'Fantasy', 'Thriller'],
#  ['Fantasy', 'Horror'],
#  ['Biography', 'Drama', 'Music'],
#  ['Comedy', 'Crime', 'Romance'],
#  ['Action', 'Drama', 'Horror'],
#  ['Adventure', 'Comedy', 'Crime'],
#  ['Drama', 'Music', 'Musical'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Adventure', 'Drama', 'Horror'],
#  ['Drama', 'Musical', 'Romance'],
#  ['Crime', 'Drama', 'Fantasy'],
#  ['Adventure', 'Fantasy', 'Mystery'],
#  ['Romance', 'Sci-Fi', 'Thriller'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Action', 'Biography', 'Comedy'],
#  ['Comedy', 'Family'],
#  ['Adventure', 'Comedy', 'Fantasy'],
#  ['Crime', 'Drama', 'History'],
#  ['Biography', 'Documentary', 'Family'],
#  ['Adventure', 'Drama', 'Mystery'],
#  ['Adventure', 'Drama', 'Thriller'],
#  ['Biography', 'Documentary', 'Sport'],
#  ['Sport'],
#  ['Comedy', 'Drama', 'Thriller'],
#  ['Documentary', 'Fantasy', 'Mystery'],
#  ['Adventure', 'Drama', 'History'],
#  ['Drama', 'War'],
#  ['Comedy', 'Music'],
#  ['Animation', 'Fantasy', 'Musical'],
#  ['Animation', 'Family', 'Fantasy'],
#  ['Family', 'Fantasy'],
#  ['Animation', 'Drama', 'Fantasy'],
#  ['Action', 'Comedy', 'Sport'],
#  ['Fantasy', 'Horror', 'Mystery'],
#  ['Action', 'Fantasy', 'Western'],
#  ['Comedy', 'Crime'],
#  ['Drama', 'History', 'Thriller'],
#  ['Adventure', 'Comedy', 'Music'],
#  ['Horror', 'Mystery'],
#  ['Adventure', 'Comedy', 'Sci-Fi'],
#  ['Comedy', 'Drama', 'Sport'],
#  ['Comedy', 'Horror', 'Thriller'],
#  ['Biography', 'Drama', 'Family'],
#  ['Western'],
#  ['Drama', 'Horror', 'Sci-Fi'],
#  ['Drama', 'Family', 'Sport'],
#  ['Drama', 'Fantasy', 'Thriller'],
#  ['Action', 'Documentary'],
#  ['Horror', 'Mystery', 'Sci-Fi'],
#  ['Action', 'History'],
#  ['Drama', 'Family', 'Romance'],
#  ['Drama', 'Music'],
#  ['Drama', 'Music', 'Romance'],
#  ['Documentary', 'Music'],
#  ['Comedy', 'Sci-Fi'],
#  ['Biography', 'Drama', 'War'],
#  ['Adventure', 'Biography', 'Drama'],
#  ['Adventure', 'Drama', 'Western'],
#  ['Adventure', 'Documentary', 'Drama'],
#  ['Crime', 'Drama', 'Horror'],
#  ['Sci-Fi', 'Thriller'],
#  ['Drama', 'Fantasy'],
#  ['Animation', 'Comedy', 'Drama'],
#  ['Fantasy', 'Thriller'],
#  ['Comedy', 'Romance', 'Sport'],
#  ['Documentary', 'Drama', 'War'],
#  ['Adventure', 'Comedy', 'Romance'],
#  ['Comedy', 'Horror', 'Sci-Fi'],
#  ['Adventure', 'Documentary'],
#  ['Biography', 'Documentary', 'Music'],
#  ['Biography', 'Comedy', 'Documentary'],
#  ['Comedy', 'Horror', 'Romance'],
#  ['Comedy', 'Fantasy', 'Romance'],
#  ['Comedy', 'Crime', 'Thriller'],
#  ['Comedy', 'Horror'],
#  ['Adventure', 'Animation', 'Documentary'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Action', 'Sport'],
#  ['Action', 'Biography', 'Crime'],
#  ['Drama', 'History', 'Sport'],
#  ['Animation', 'Sci-Fi'],
#  ['Adventure', 'Documentary', 'Music'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Action', 'Comedy', 'Mystery'],
#  ['Action', 'Adventure', 'Documentary'],
#  ['Action', 'Drama', 'Sport'],
#  ['Drama', 'Romance', 'War'],
#  ['Action', 'Horror', 'Mystery'],
#  ['Fantasy', 'Horror', 'Thriller'],
#  ['Action', 'Romance', 'Sport'],
#  ['Drama', 'Mystery'],
#  ['Adventure', 'Documentary', 'War'],
#  ['Drama', 'History', 'Romance'],
#  ['Action', 'Drama', 'Western'],
#  ['Biography', 'Drama', 'Mystery'],
#  ['Drama', 'Mystery', 'Romance'],
#  ['Adventure', 'Documentary', 'Sport'],
#  ['Drama', 'Music', 'Thriller'],
#  ['Family', 'Horror', 'Romance'],
#  ['Action', 'Romance', 'Thriller'],
#  ['Drama', 'Fantasy', 'Mystery'],
#  ['Comedy', 'Music', 'Romance'],
#  ['Drama', 'Fantasy', 'Sci-Fi'],
#  ['Action', 'Comedy', 'Documentary'],
#  ['Crime', 'Horror', 'Mystery'],
#  ['Documentary', 'Western'],
#  ['Comedy', 'Mystery', 'Sci-Fi'],
#  ['Comedy', 'Mystery', 'Thriller'],
#  ['Comedy', 'Drama', 'Fantasy'],
#  ['Crime', 'Fantasy', 'Thriller'],
#  ['Comedy', 'Sport'],
#  ['Adventure', 'Documentary', 'History'],
#  ['Drama', 'Family', 'Music'],
#  ['Documentary', 'War'],
#  ['Comedy', 'Documentary'],
#  ['Action', 'Horror', 'Thriller'],
#  ['Animation', 'Drama'],
#  ['Adventure', 'Biography', 'Comedy'],
#  ['Horror', 'Music', 'Thriller'],
#  ['Comedy', 'Music', 'War'],
#  ['Documentary', 'History', 'Western'],
#  ['Biography'],
#  ['Adventure', 'Animation'],
#  ['Action', 'Documentary', 'Drama'],
#  ['Adventure', 'Family', 'Sci-Fi'],
#  ['Drama', 'Thriller', 'War'],
#  ['Biography', 'Comedy', 'Crime'],
#  ['Drama', 'Mystery', 'War'],
#  ['Comedy', 'Drama', 'Mystery'],
#  ['Documentary', 'Drama', 'News'],
#  ['Adventure', 'Crime', 'Drama'],
#  ['Family', 'Fantasy', 'Music'],
#  ['Drama', 'Fantasy', 'Music'],
#  ['Adventure', 'Horror', 'Sci-Fi'],
#  ['Adventure', 'Comedy', 'Horror'],
#  ['Drama', 'History', 'Mystery'],
#  ['Comedy', 'Horror', 'Mystery'],
#  ['Action', 'Horror'],
#  ['Biography', 'Family', 'Sport'],
#  ['Comedy', 'Drama', 'Horror'],
#  ['Drama', 'Family', 'Thriller'],
#  ['Horror', 'Romance'],
#  ['Documentary', 'History', 'Mystery'],
#  ['Comedy', 'Thriller'],
#  ['Horror', 'Sci-Fi'],
#  ['Adventure', 'Family'],
#  ['Crime', 'Mystery', 'Sci-Fi'],
#  ['Crime', 'Drama', 'Musical'],
#  ['Documentary', 'Sport', 'Thriller'],
#  ['Drama', 'Family', 'History'],
#  ['Fantasy', 'Horror', 'Sci-Fi'],
#  ['Adventure', 'Fantasy', 'Horror'],
#  ['Adventure', 'Horror', 'Mystery'],
#  ['Animation', 'Documentary', 'Sci-Fi'],
#  ['Animation', 'Horror'],
#  ['Crime', 'Drama', 'Romance'],
#  ['Drama', 'Musical'],
#  ['Animation', 'Family'],
#  ['Drama', 'Family', 'Mystery'],
#  ['Action', 'Crime', 'Horror'],
#  ['Adventure', 'Crime', 'Thriller'],
#  ['Horror', 'Romance', 'Thriller'],
#  ['Biography', 'Drama', 'Fantasy'],
#  ['Comedy', 'Fantasy', 'Sci-Fi'],
#  ['Crime', 'Documentary', 'History'],
#  ['Drama', 'Thriller', 'Western'],
#  ['Crime', 'Documentary'],
#  ['Comedy', 'Fantasy', 'Musical'],
#  ['Documentary', 'Drama', 'History'],
#  ['Documentary', 'History', 'War'],
#  ['Biography', 'Documentary', 'War'],
#  ['Comedy', 'Romance', 'Thriller'],
#  ['Comedy', 'Crime', 'Horror'],
#  ['Adventure', 'Horror'],
#  ['Music', 'War'],
#  ['Documentary', 'Music', 'War'],
#  ['Documentary', 'Drama', 'Reality-TV'],
#  ['Comedy', 'Fantasy', 'Thriller'],
#  ['Documentary', 'Horror'],
#  ['Documentary', 'Family', 'History'],
#  ['Action', 'Biography', 'Documentary'],
#  ['History'],
#  ['Horror', 'Musical'],
#  ['Family', 'Sci-Fi'],
#  ['Romance', 'Thriller']]

# %%
# FOR NON_SEPARATED CASE
# Creating a list of top 10 genres
# topten_genres = list(df.genres.value_counts().head(10).index)

# %%
# FOR NON_SEPARATED CASE
# # Use for loop to create regression plots and calcurate correlation efficient for each of the top ten genres.
# for genre in topten_genres:
#     # filter by genre
#     df_bygenre = df.loc[df['genres'] == genre]

#     # change data type to int and change unit to $MM
#     df_bygenre['production_budget'] = df_bygenre['production_budget'].map(remove_dollar).astype(int).map(lambda x: round(x / 1000000))
#     df_bygenre['domestic_gross'] = df_bygenre['domestic_gross'].map(remove_dollar).astype(int).map(lambda x: round(x / 1000000))
#     df_bygenre['worldwide_gross'] = df_bygenre['worldwide_gross'].map(remove_dollar).map(million)
#     df_bygenre['total_revenue'] = df_bygenre['domestic_gross'] + df_bygenre['worldwide_gross']
    
#     # create regplot using 
#     plt.figure()
#     plt.title(genre)
#     sns.regplot(data=df_bygenre, x='production_budget', y='total_revenue')
    
#     print(genre)
#     print(np.corrcoef(df_bygenre['production_budget'], df_bygenre['total_revenue']))

# %%
# Using for-loop to create regression plots and calcurate correlation coeffiient for each of the top ten genres.

for genre in topten_genres_separated:
    # filter by genre
    df_bygenre = df_new[df_new['genres'].str.contains(genre)]
    
    # create regplot using 
    plt.figure()
    plt.title(genre)
    sns.regplot(data=df_bygenre, x='production_budget', y='total_revenue')
    
    print(genre)
    print(np.corrcoef(df_bygenre['production_budget'], df_bygenre['total_revenue']))
    print(stats.linregress(df_bygenre['production_budget'], df_bygenre['total_revenue']))


# explain how to weight genres from multiple
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-152-0379b9695a15> in <module>
#       3 for genre in topten_genres_separated:
#       4     # filter by genre
# ----> 5     df_bygenre = df_new[df_new['genres'].str.contains(genre)]
#       6
#       7     # create regplot using
#
# NameError: name 'df_new' is not defined
